# %% [markdown]
# # Getting Stock Prices for our Data Set

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import urllib

# %%
# This doesn't seem to work
# using the yahoo finance API

def graph_data(stock):
    print("Currently pulling:",stock)
    url = "http://chartapi.finance.yahoo.com/instrument/1.0/"+stock+"/chartdata;type=quote;range=10y/csv"
    print(url)

# %%
stock = input("Stock to plot: ")
stock = stock.upper()
graph_data(stock)
# Out:
# Stock to plot: tsla
# Currently pulling: TSLA
# http://chartapi.finance.yahoo.com/instrument/1.0/TSLA/chartdata;type=quote;range=10y/csv

# %%
data = np.genfromtxt("F:/Google Drive/JupyterNotebooks/Matplotlib Course/HistoricalQuotes.csv",delimiter = ",",dtype=[str,float,float,float,float,float])

# %%
data
# Out:
# array([[ nan,  nan,  nan,  nan,  nan,  nan],
#        [ nan,  nan,  nan,  nan,  nan,  nan],
#        [ nan,  nan,  nan,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan,  nan,  nan,  nan],
#        [ nan,  nan,  nan,  nan,  nan,  nan],
#        [ nan,  nan,  nan,  nan,  nan,  nan]])

# %%
import pandas as pd

pd_data = pd.read_csv("F:/Google Drive/JupyterNotebooks/Matplotlib Course/HistoricalQuotes.csv",delimiter=",")
pd_data.head(5)
# Out:
#          date   close     volume      open      high       low
# 0  2018/05/11  301.06  4665321.0  307.7000  308.8800  299.0800
# 1  2018/05/10  305.02  5642771.0  307.4997  312.9900  304.1119
# 2  2018/05/09  306.85  5712255.0  300.4100  307.0100  300.0500
# 3  2018/05/08  301.97  5927447.0  300.7950  307.7500  299.0000
# 4  2018/05/07  302.77  8673090.0  297.5000  305.9588  295.1700

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-53de50c5fae8> in <module>()
# ----> 1 pd_data.apply(lambda x: pd["date"].Timestamp(x),axis=1)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
# ...
