# %%
import pandas as pd
import matplotlib as plt
import numpy as np
# %matplotlib inline

# %%
data_raw = pd.read_html("http://aquatext.com/tables/algaegrwth.htm")
data_raw = data_raw[1]
#data_raw.dropna(axis=0,inplace=True)

# %%
"""replace_row = ["Temperature",5.00,5.00,10.00,10.00,25.00,25.00,30.00,30.00]
current_row = list(data_raw.transpose()[0])[1:]
print(current_row)
replace_dict = dict(zip(current_row,replace_row))
print(replace_dict)"""
# Out:
# [5.0, 10.0, '25', 30.0, nan, nan, nan, nan]
# {nan: 25.0, nan: 25.0, 5.0: 5.0, nan: 30.0, '25': 10.0, 10.0: 5.0, 30.0: 10.0, nan: 30.0}

# %%
data_raw.loc[1] = ["Temperature",5.00,5.00,10.00,10.00,25.00,25.00,30.00,30.00] # adding a row
# data_raw.index = data_raw.index+1 # shifting index
data_raw = data_raw.sort_index()  # sorting by index

# %%
data_raw.drop(data_raw.index[0], inplace=True)
data_raw.i
for i in data_raw[3]
# Out:
#                                    0     1     2      3      4      5      6  \
# 1                        Temperature  5.00  5.00     10  10.00  25.00  25.00
# 2                            Species   NaN   NaN    NaN    NaN    NaN    NaN
# 3                 Caloneis schroderi -0.01 -0.50   -0.1   0.25   0.28   0.30
# 4               Chaetoceros gracilis -0.01 -0.05   0.16   0.07   0.52   0.39
# 5                Chaetoceros simplex -0.06 -0.01   0.27   0.55   0.47   0.52
# 6              Chlorella ellipsoidea  0.03  0.02   0.58   0.53   0.88   0.85
# 7            Chlorella stigmatophora  0.01  0.24   0.36   0.24   0.78   0.56
# 8   Chlorella vulgaris  (freshwater) -0.25  0.00   0.21   0.17   0.68   0.67
# 9             Dunaniella tertiolecta  0.28  0.17   0.43   0.42   0.60   0.64
# 10             Cyclotella sp. NUFP-9  0.16  0.08   0.00  -0.10   0.00   0.00
# 11                   Hanzchia marina -0.36 -0.07  -0.68  -0.21   0.21   0.15
# ...

# %%
sns.violinplot(data=data_raw, x="Lux",y="Divisions per Day")

# %%
data_t = data_raw.transpose()

# %%
data_t
# Out:
#                                         1                     2   \
# Light  Intensity (lux)  Caloneis schroderi  Chaetoceros gracilis
# 5000                                 -0.01                 -0.01
# 2500                                  -0.5                 -0.05
# 5000.1                                -0.1                  0.16
# 2500.1                                0.25                  0.07
# 5000.2                                0.28                  0.52
# 2500.2                                 0.3                  0.39
# 5000.3                                0.38                  0.62
# 2500.3                                0.29                  0.73
#
#                                          3                      4   \
# Light  Intensity (lux)  Chaetoceros simplex  Chlorella ellipsoidea
# 5000                                  -0.06                   0.03
# 2500                                  -0.01                   0.02
# ...

# %%
data_t = data_t.rename(columns=data_t.iloc[0]).drop(data_t.index[0])

# %%
data_t
# Out:
#        Caloneis schroderi Chaetoceros gracilis Chaetoceros simplex  \
# 5000                -0.01                -0.01               -0.06
# 2500                 -0.5                -0.05               -0.01
# 5000.1               -0.1                 0.16                0.27
# 2500.1               0.25                 0.07                0.55
# 5000.2               0.28                 0.52                0.47
# 2500.2                0.3                 0.39                0.52
# 5000.3               0.38                 0.62                0.54
# 2500.3               0.29                 0.73                0.63
#
#        Chlorella ellipsoidea Chlorella stigmatophora  \
# 5000                    0.03                    0.01
# 2500                    0.02                    0.24
# 5000.1                  0.58                    0.36
# 2500.1                  0.53                    0.24
# 5000.2                  0.88                    0.78
# ...

# %%
help(sns.violinplot)
# Out:
# Help on function violinplot in module seaborn.categorical:
#
# violinplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw='scott', cut=2, scale='area', scale_hue=True, gridsize=100, width=0.8, inner='box', split=False, orient=None, linewidth=None, color=None, palette=None, saturation=0.75, ax=None, **kwargs)
#     Draw a combination of boxplot and kernel density estimate.
#
#     A violin plot plays a similar role as a box and whisker plot. It shows the
#     distribution of quantitative data across several levels of one (or more)
#     categorical variables such that those distributions can be compared. Unlike
#     a box plot, in which all of the plot components correspond to actual
#     datapoints, the violin plot features a kernel density estimation of the
#     underlying distribution.
#
#     This can be an effective and attractive way to show multiple distributions
#     of data at once, but keep in mind that the estimation procedure is
# ...

# %%
sns.violinplot(data=data_t)
