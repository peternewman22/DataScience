# %%
import pandas as pd
import requests

# %%
podcastData = pd.read_csv("Podcasts Playstate.csv")

# %%
podcastData
# Out:
#                                         Feed URL  \
# 0                    http://20khz.libsyn.com/rss
# 1                    http://20khz.libsyn.com/rss
# 2                    http://20khz.libsyn.com/rss
# 3                    http://20khz.libsyn.com/rss
# 4                    http://20khz.libsyn.com/rss
# ...                                          ...
# 10557  https://www.unmade.fm/episodes?format=rss
# 10558  https://www.unmade.fm/episodes?format=rss
# 10559  https://www.unmade.fm/episodes?format=rss
# 10560  https://www.unmade.fm/episodes?format=rss
# 10561  https://www.unmade.fm/episodes?format=rss
#
#                                               Episode ID  Visible?  \
# 0                       0261aed81b30bea72c66d60fcc530533       NaN
# 1                   05f40f20-0bcb-11ea-9f82-878960655fd8       NaN
# 2                       0a745b3f6ddf4ea2d65452e77b661193       NaN
# 3                   0f792a22-1526-11e9-aabb-bfe055a7b255       NaN
# ...

# %%
class iTunesRequest:
    def __init__(self, IDs):
        self.params = {'id' : IDs,
                      'media' : 'podcast',
                      'limit' : 200}
        
    def search
